# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y)

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()
plt.scatter(x,y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f09ba60e910>,
#   <matplotlib.lines.Line2D at 0x7f09ba60ee50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f09ba6133d0>,
#   <matplotlib.lines.Line2D at 0x7f09ba613910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f09ba60e410>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f09ba601690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f09ba61b390>],
#  'means': []}

# %%
plt.boxplot(x)
plt.show()

# %%
x1=np.linspace(0,5,11)
y1=x**2

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r-')
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# sns.displot(data=tips, x='total_bill',hue='sex',kind='kde')

# %% [markdown]
# ##DISTRIBUCIONES

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.displot(data=tips)
# sns.displot(data=tips, x='total_bill',hue='sex',kind='kde')

# %%
sns.histplot(data=tips,x='tip',bins=15,cumulative=False, hue='sex',stat='count',multiple='dodge')

# %%
sns.kdeplot(data=tips,x='tip',hue='sex',cumulative=False, shade=True,bw_adjust=1)

# %%
tips=sns.load_dataset('tips')
sns.countplot(data=tips,x='day')

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
plt.legend(loc='center',bbox_to_anchor=(1.12,0.6))
plt.figure(figsize=(6,6))
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head(2)
import matplotlib.pyplot as plt
sns.displot(tips)

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',hue='sex',kind='hist',marginal_ticks=True,marginal_kws=dict(bins=25,fill=False,multiple='dodge'))
plt.show()

# %%
sns.pairplot(data=tips,hue='sex',palette='coolwarm',corner=True)
plt.show()
