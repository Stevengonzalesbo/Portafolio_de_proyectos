# %%
import pandas as pd
import numpy as np

# %%
dict={'col1': [1,2,3,np.nan],
 'col2':[4,np.nan,6,7],
 'col3':['a','b','c',None]}

# %%
df = pd.DataFrame(dict)
df
# Out:
#    col1  col2  col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %%
df.fillna('Missing')
# Out:
#       col1     col2     col3
# 0      1.0      4.0        a
# 1      2.0  Missing        b
# 2      3.0      6.0        c
# 3  Missing      7.0  Missing

# %%
df.interpolate()
# Out:
#    col1  col2  col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %%
df.dropna()
# Out:
#    col1  col2 col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c
